# %%
sami=ovi=proyash=25
print(sami)
# Out:
# 25

# %%
print(sami,ovi)
# Out:
# 25 25

# %%
name='nazmul hassan ovi'
x=name.replace('a','xx')
print(x)
# Out:
# nxxzmul hxxssxxn ovi

# %%
print(name*9)
# Out:
# nazmul hassan ovinazmul hassan ovinazmul hassan ovinazmul hassan ovinazmul hassan ovinazmul hassan ovinazmul hassan ovinazmul hassan ovinazmul hassan ovi

# %%
print(x.replace('xx',''))
# Out:
# nzmul hssn ovi

# %%
print(x.title())
# Out:
# Nxxzmul Hxxssxxn Ovi

# %%
name='      asa    as   '
print(name)
# Out:
#       asa    as

# %%
print(name.strip())
# Out:
# asa    as

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
name=input('What is your name: ')
print(name)
print(type(int(name)))
# Out:
# 5
# <class 'int'>

# %%
import math
pi=3.5
print(round(pi))
# Out:
# 4

# %%
print(math.ceil(pi))
# Out:
# 4

# %%
print(math.floor(pi))
# Out:
# 3

# %%
x,y,z,xx=10,30,20,90
print(xx)
# Out:
# 90

# %%
print(min(x,y,z))
print(max(x,y,z))
# Out:
# 10
# 30

# %% [markdown]
# [start:stop:step]

# %%
x=[3,4,5,6,7,8,4,3,6,8,9]
print(x[::-3])
# Out:
# [9, 3, 7, 4]

# %%
name='Nazmul Hassan Ovi'
print(name[slice(14,17)])
# Out:
# Ovi

# %% [markdown]
# args

# %%
def add(*a):
    print(a)
    num=1
    for i in a:
        print(num,':',i)
        num+=1

add(1,2,5,1,1,2,4,6,7,8,9,4,5,6,7,8,9,2,3,4,5,6)
# Out:
# (1, 2, 5, 1, 1, 2, 4, 6, 7, 8, 9, 4, 5, 6, 7, 8, 9, 2, 3, 4, 5, 6)
# 1 : 1
# 2 : 2
# 3 : 5
# 4 : 1
# 5 : 1
# 6 : 2
# 7 : 4
# 8 : 6
# 9 : 7
# 10 : 8
# 11 : 9
# 12 : 4
# 13 : 5
# 14 : 6
# 15 : 7
# 16 : 8
# 17 : 9
# 18 : 2
# 19 : 3
# 20 : 4
# 21 : 5
# 22 : 6

# %%
def hello(**kwargs):
    for x,y in kwargs.items():
        print(x,y,end=' ')

hello(name='Faysal Mahmud', role='SWE')
# Out:
# name Faysal Mahmud role SWE

# %% [markdown]
# # List, Tuple, Set, Dictionary

# %%
list1=[1,2,'asas',True]
print(list1)
# Out:
# [1, 2, 'asas', True]

# %%
sentence="ami banglai gan gai, ami banglai gan gai"
list1=(sentence.split())
print(list1)
# Out:
# ['ami', 'banglai', 'gan', 'gai,', 'ami', 'banglai', 'gan', 'gai']

# %%
fruits=['apple','banana','cherry','orange']
fruits[1:1]=['blackberry','papa']

print(fruits)
# Out:
# ['apple', 'blackberry', 'papa', 'banana', 'cherry', 'orange']

# %%
num=[1,2,3]
num[1:2]=[300]
print(num)
# Out:
# [1, 300, 3]

# %%
thislist = ["apple", "banana", "cherry"]
thislist.insert(2, "watermelon")
print(thislist)
# Out:
# ['apple', 'banana', 'watermelon', 'cherry']

# %%
newlist=[x for x in thislist if not "a" in x]
print(newlist)
# Out:
# ['cherry']

# %%
try:
    thislist.remove('banana')
except :
    print(thislist)
# Out:
# ['apple', 'watermelon', 'cherry']

# %%
thislist=[1,2,3,4]
thislist.extend([1,2,3])
print(thislist)
# Out:
# [1, 2, 3, 4, 1, 2, 3]

# %%
thislist.pop(1)
print(thislist)
# Out:
# [1, 3, 4, 1, 2, 3]

# %%
thislist.clear()
print(thislist)
# Out:
# []

# %%
# newlist = [expression for item in iterable if condition == True]

# %%
newlist=[x for x in range(10) if x<=5]
print(newlist)
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
newlist=[x if not x==1 else x for x in newlist]
newlist.sort(reverse=1)
print(newlist)
# Out:
# [5, 4, 3, 2, 0]

# %% [markdown]
# Sort

# %%
def func(n):
    return abs(n-2)

list3=[1,2,5,73,4,5]
list3.sort(key=func)
print(list3)
# Out:
# [2, 1, 4, 5, 5, 73]

# %%
list1=list3
print(list1)
# Out:
# [2, 1, 4, 5, 5, 73]

# %%
list1 = ["a", "b", "c"]
list2 = [1, 2, 3]
list1.extend( list2)
print(list1)
# Out:
# ['a', 'b', 'c', 1, 2, 3]

# %%
list1 = ["a", "b", "c"]
list2 = [1, 2, 3]

list3 = list1 + list2
print(list3)
# Out:
# ['a', 'b', 'c', 1, 2, 3]

# %%
print(list1.count('a'))
# Out:
# 1

# %% [markdown]
# Method	Description
# append()	Adds an element at the end of the list
# clear()	Removes all the elements from the list
# copy()	Returns a copy of the list
# count()	Returns the number of elements with the specified value
# extend()	Add the elements of a list (or any iterable), to the end of the current list
# index()	Returns the index of the first element with the specified value
# insert()	Adds an element at the specified position
# pop()	Removes the element at the specified position
# remove()	Removes the item with the specified value
# reverse()	Reverses the order of the list
# sort()	Sorts the list

# %%
tuple_1=(1,2,7,3,'a',"asad",[1,2,3])
print(tuple_1,type(tuple_1))
# Out:
# (1, 2, 7, 3, 'a', 'asad', [1, 2, 3]) <class 'tuple'>

# %% [markdown]
# List is a collection which is ordered and changeable. Allows duplicate members.
# Tuple is a collection which is ordered and unchangeable. Allows duplicate members.
# Set is a collection which is unordered, unchangeable*, and unindexed. No duplicate members.
# Dictionary is a collection which is ordered** and changeable. No duplicate members.

# %%
print(tuple_1[-3:])
# Out:
# ('a', 'asad', [1, 2, 3])

# %%
temp=list(tuple_1)
temp.remove('asad')
tuple_1=tuple(temp)
print(tuple_1)
print(type(tuple_1))
# Out:
# (1, 2, 7, 3, 'a', [1, 2, 3])
# <class 'tuple'>
